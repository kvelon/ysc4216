# %% [markdown]
# **Kelvin Fung**<br>
# **YSC4216 Machine Learning**<br>
# **Assignment 4: Gaussian Process for Regression**

# %% [markdown]
# Link to assignment:
#
# https://tanrobby.github.io/teaching/ync_machine_learning/assignment4.html

# %% [markdown]
# 1. Generate 50 2D-data points using the following function: $y = sin(x^2 + 1)$
# 2. Add Gaussian random noise to the data
# 3. Show original curve line and the noisy data

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# %matplotlib inline

# %%
# Functions to generate data
def actual_distribution(num_points=50):
    x_act = np.linspace(0, 1, num=num_points)
    y_act = np.sin(np.power(x_act, 2) + 1)
    
    return (x_act, y_act)

def add_noise(y_act, sig=.05):
    mu = 0
    noise = np.random.normal(mu, sig, len(y_act))
    
    return y_act + noise

# %%
x_act, y_act = actual_distribution(50)
y_noise = add_noise(y_act, .05)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x_act, y_act, '-ro', markersize=3, label='Original curve')
ax.plot(x_act, y_noise, '-gx', linestyle='none', label='Noisy data')
ax.legend()

# %% [markdown]
# 4. Compute the Gaussian process prediction of every input data sequentially, where each input data is taken randomly from the noise data.
# 5. Use the kernel we discuss in class (textbook's Eq. (6.63), page 307), by setting thetas: (1.0, 4.0, 0.0, 0.0)

# %%
def gaussian_process(x_act, y_noise, beta, thetas):
    
    # Define kernel function
    def k(xi, xj):
        return thetas[0] * np.exp((-thetas[1]/2) * linalg.norm(xi-xj)**2) + thetas[2] + \
               (thetas[3] * (xi.T * xj)[0, 0])
        
    # Define functions to compute k_star and C_n
    def compute_k_star(x_star, x_train, kernel_func):
        return np.matrix([kernel_func(np.matrix(x), np.matrix(x_star)) for x in x_train]).T
    
    def compute_C_N(x_train, kernel_func, beta):
        N = len(x_train)
        C_N = np.zeros((N, N))
        
        for i, x in enumerate(x_train):
            C_N[i, i] = kernel_func(np.matrix(x), np.matrix(x)) + (1/beta)
            
            for j in range(i+1, N):
                C_N[i, j] = kernel_func(np.matrix(x), np.matrix(x_train[j]))
                C_N[j, i] = C_N[i, j]
                
        return C_N
                
    def compute_c_star(x_star, kernel_func, beta):
        return kernel_func(np.matrix(x_star), np.matrix(x_star)) + (1/beta)
    
    # Create array to store order in which data is sampled.
    sampling_order = [n for n in range(len(x_act))]
    np.random.shuffle(sampling_order)
    
    # Initilise variables to store predicted values and associated s.d.
    y_est_lst = []
    s_lst = []
    
    # Insert data one at a time and compute estimated y and s.d.
    x_train = []
    y_train = []
    
    for index in sampling_order:
        x_train.append(x_act[index])
        y_train.append(y_noise[index])
        
        y_est = []
        sd = []
        
        C_N = compute_C_N(x_train, k, beta)
                
        C_N_inv = linalg.inv(C_N)
        t_N = np.matrix(y_train).T
        
        for x_star in x_act:
            
            k_star = compute_k_star(x_star, x_train, k) 
            c_star = compute_c_star(x_star, k, beta)
            
            y_est.append((k_star.T * C_N_inv * t_N)[0,0])
            sd.append((c_star - (k_star.T * C_N_inv * k_star))[0,0])
            
        y_est_lst.append(y_est)
        s_lst.append(sd)
        
    return y_est_lst, s_lst

# %% [markdown]
# 6. Experiment with your code by changing beta, and explain what beta is for and how it affects the results.

# %%
def plot_few(x_act, y_act, y_noise, to_plot, beta, thetas):
    
    y_est_lst, s_lst = gaussian_process(x_act, y_noise, beta, thetas)
    
    fig = plt.figure(figsize=[12,15])
    fig.suptitle("Beta = {}".format(beta), fontsize=32, y=0.95)
    
    index=1
    for plot_num in to_plot:
        ax = fig.add_subplot(4, 2, index)

        ax.plot(x_act, y_act, '-ro', markersize=3, label='Original curve')
        ax.plot(x_act, y_noise, '-gx', linestyle='none', label='Noisy data')
        ax.errorbar(x_act, y_est_lst[plot_num-1], yerr=s_lst[plot_num-1], 
                    marker="^", linestyle='none', capsize=2)
        ax.text(0.05, 0.9, "No. of points: {}".format(plot_num), transform=ax.transAxes)
        index += 1

# %%
to_plot = [1, 2, 3, 5, 10, 15, 25, 50]

# %%
plot_few(x_act, y_act, y_noise, to_plot, 1, [1, 4, 0, 0])

# %%
plot_few(x_act, y_act, y_noise, to_plot, 10, [1, 4, 0, 0])

# %%
plot_few(x_act, y_act, y_noise, to_plot, 20, [1, 4, 0, 0])

# %% [markdown]
# Beta inverse is the covariance matrix of the likelihood probability distribution, $p(\overline{t}_N | \overline{y}_N)$. Hence when we set beta to be a low value, beta inverse will be high. Conversely, when we set beta to be a high value, beta inverse will be low.
#
# Since beta is the covariance matrix of the likelihood probability distribution, it means that it controls how much variability the model expects around its mean. We see that when beta is low (which means beta inverse is high), the error bars were wider, and when beta is high, the error bars were narrower.

# %% [markdown]
# 7. Show your best prediction results for all 50 data one by one:

# %%
y_est_lst, s_lst = gaussian_process(x_act, y_noise, 15, [1, 4, 0, 0])

# %%
plot_num = 1

fig = plt.figure(figsize=[15, 30])
fig.suptitle("Best Prediction with Beta=15", y=0.93, fontsize=32)

for y_est, y_error in zip(y_est_lst, s_lst):

    ax = fig.add_subplot(17, 3, plot_num)

    ax.plot(x_act, y_act, '-ro', markersize=3, label='Original curve')
    ax.plot(x_act, y_noise, '-gx', linestyle='none', label='Noisy data')
    ax.errorbar(x_act, y_est_lst[plot_num-1], yerr=s_lst[plot_num-1], 
                marker="^", linestyle='none', capsize=2)    
    ax.text(0.05, 0.9, "No. of points: {}".format(plot_num), transform=ax.transAxes)
    plot_num += 1

# %% [markdown]
# 8. Change the kernel's parameters, thetas: (1, 64, 10, 5) and show the results.

# %%
plot_few(x_act, y_act, y_noise, to_plot, 15, [1, 64, 10, 5])

# %% [markdown]
# 9. Explain the effects of changing to this kernel on the prediction.

# %% [markdown]
# Changing to this kernel had caused the fitted line to be more overfitted to the noisy data. Compared to the previous kernel, which gave a smooth curve, this new curve has numerous inflexions and turns.

# %% [markdown]
# 10. Change the kernel's parameters, thetas: (1.00, 0.25, 0.00, 0.00) and show the results.

# %%
plot_few(x_act, y_act, y_noise, to_plot, 15, [1, 0.25, 0, 0])

# %% [markdown]
# 11. Explain the effects of changing to this kernel on the prediction.

# %% [markdown]
# Changing to this kernel had the opposite effect: it caused the curve to be underfitted. After all 50 sequences of training, the curve still does not fit the underlying model well.
